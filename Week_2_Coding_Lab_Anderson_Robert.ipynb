# %% [markdown]
# <a href="https://colab.research.google.com/github/randerson2113/CSC7002PythonCourse/blob/main/Week_2_Coding_Lab_Anderson_Robert.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #List Comprehensions and Filters:
# Write a Python program that uses a list comprehension to generate a list of the squares of the numbers from 1 to 10. Then, use the filter function to keep only the odd numbers squares.

# %%
#use list comprehension to generate a list of squares from 1 - 10. keep only odd number's squares
squares = [x**2 for x in range(1, 11)]
odd_squares = list(filter(lambda x: x % 2 != 0, squares))
print(odd_squares)
# Out:
# [1, 9, 25, 49, 81]

# %% [markdown]
# #Generators and Tuples:
# Write a Python generator function that generates Fibonacci sequence.
# The function should return a tuple with the index and the Fibonacci number for each call. Use the generator to print the first 10 Fibonacci numbers.

# %%
# Write a Python generator function that generates Fibonacci sequence. The function should return a tuple with the index and the Fibonacci number for each call. Use the generator to print the first 10 Fibonacci numbers.
def fibonacci_generator(n):
  a, b = 0, 1
  for i in range(n):
      #return the output in a tuple
      yield (i, a)
      a, b = b, a + b

def mathematical_fibonacci(n):
  a, b = 0,1
  for i in range(n):
    yeild(i, a)
    a, b = i,


sequence = tuple(fibonacci_generator(10))
print(sequence)
print(fibonacci_generator(10))
# Out:
# (0, 0)
# (0, 0)

# %% [markdown]
# #Maps and Reduces:
# Write a Python program that uses the map function to calculate the cube of each number in a list.
# Then, use the reduce function from the functools module to find the sum of the cubes.

# %%
#Write a Python program that uses the map function to calculate the cube of each number in a list. Then, use the reduce function from the functools module to find the sum of the cubes.
def cube(*args):

# %% [markdown]
# #Word Frequency with Dictionaries:
# Write a Python program that takes a sentence as input from the user and uses a dictionary to store the frequency of each word in the sentence.
# The keys in the dictionary should be the words, and the values should be the frequencies.

# %% [markdown]
# #Unique Elements with Sets:
# Write a Python program that takes a list of numbers as input from the user and uses a set to find and print the unique numbers in the list.
