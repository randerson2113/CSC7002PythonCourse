# %% [markdown]
# <a href="https://colab.research.google.com/github/randerson2113/CSC7002PythonCourse/blob/main/Deitel_12_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### All work done in this notebook belongs to the original author and publisher, and was compiled for presentation purposes only.

# %%
##########################################################################
# (C) Copyright 2019 by Deitel & Associates, Inc. and                    #
# Pearson Education, Inc. All Rights Reserved.                           #
#                                                                        #
# DISCLAIMER: The authors and publisher of this book have used their     #
# best efforts in preparing the book. These efforts include the          #
# development, research, and testing of the theories and programs        #
# to determine their effectiveness. The authors and publisher make       #
# no warranty of any kind, expressed or implied, with regard to these    #
# programs or to the documentation contained in these books. The authors #
# and publisher shall not be liable in any event for incidental or       #
# consequential damages in connection with, or arising out of, the       #
# furnishing, performance, or use of these programs.                     #
##########################################################################

# %% [markdown]
# ## Run these statements to reduce exceptions / errors later!

# %%
# %pip install nltk

# %% [markdown]
# ## 12.2.1 Create a TextBlob

# %%
from textblob import TextBlob

# %%
text = 'Today is a beautiful day. Tomorrow looks like bad weather.'

# %%
blob = TextBlob(text)

# %%
blob

# %% [markdown]
# # 12.2.1 Self Check

# %% [markdown]
# **1. _(Fill-In)_** `________` is the fundamental class for NLP with the `textblob` module.
#
# **Answer:** `TextBlob`.

# %% [markdown]
# **2. _(True/False)_** `TextBlob`s support string methods and can be compared with strings using the comparison operators.
#
# **Answer:** True.

# %% [markdown]
# **3. _(IPython Session)_** Create a `TextBlob` containing `'This is a TextBlob'`.
#
# **Answer:**

# %%
exercise_blob = TextBlob('This is a TextBlob')

# %%
exercise_blob

# %% [markdown]
# ## 12.2.2 Tokenizing Text into Sentences and Words

# %%
blob.sentences

# %%
blob.words

# %% [markdown]
# # 12.2.2 Self Check

# %% [markdown]
# **1. _(IPython Session)_** Create a `TextBlob` with two sentences, then tokenize it into `Sentence`s and `Word`s, displaying all the tokens.
#
# **Answer:**

# %%
from textblob import TextBlob

# %%
ex = TextBlob('My old computer is slow. My new one is fast.')

# %%
ex.sentences

# %%
ex.words

# %% [markdown]
# ## 12.2.3 Parts-of-Speech Tagging

# %%
blob

# %%
blob.tags

# %% [markdown]
# <img alt="Check mark indicating Self Check exercises." src="files/art/check.png" style=\"float:left;border-style:solid; border-width:1px\" />
#
# # 12.2.3 Self Check

# %% [markdown]
# **1. _(Fill-In)_** `________` is the process of evaluating words based on their context to determine each word’s part of speech
#
# **Answer:** Parts-of-speech (POS) tagging.

# %% [markdown]
# **2. _(IPython Session)_** Display the parts-of-speech tags for the sentence, `'My dog is cute'`.
#
# ```
# TextBlob('My dog is cute').tags
# ```
#
# **Answer:**

# %%
TextBlob('My dog is cute').tags

# %% [markdown]
# # 12.2.4 Extracting Noun Phrases

# %%
blob

# %%
blob.noun_phrases

# %% [markdown]
# <img alt="Check mark indicating Self Check exercises." src="files/art/check.png" style=\"float:left;border-style:solid; border-width:1px\" />
#
# # 12.2.4 Self Check

# %% [markdown]
# **1. _(IPython Session)_** Show the noun phrase(s) in the sentence, `'The red brick factory is for sale'`.
#
# **Answer:**

# %%
TextBlob('The red brick factory is for sale').noun_phrases

# %% [markdown]
# # 12.2.5 Sentiment Analysis with TextBlob’s Default Sentiment Analyzer

# %% [markdown]
# ### Getting the Sentiment of a TextBlob

# %%
blob

# %%
blob.sentiment

# %% [markdown]
# ### Getting the polarity and subjectivity from the Sentiment Object

# %%
# %precision 3

# %%
blob.sentiment.polarity

# %%
blob.sentiment.subjectivity

# %% [markdown]
# ### Getting the Sentiment of a Sentence

# %%
for sentence in blob.sentences:
    print(sentence.sentiment)

# %% [markdown]
# # 12.2.5 Self Check

# %% [markdown]
# **1. _(IPython Session)_** Import `Sentence` from the `TextBlob` module then use `Sentence` objects to check the sentiment of the three sentences used in this section’s introduction.
#
# **Answer:**

# %%
from textblob import Sentence

# %%
Sentence('The food is not good.').sentiment

# %%
Sentence('The movie was not bad.').sentiment

# %%
Sentence('The movie was excellent!').sentiment

# %% [markdown]
# # 12.2.6 Sentiment Analysis with the NaiveBayesAnalyzer

# %%
from textblob.sentiments import NaiveBayesAnalyzer

# %%
blob = TextBlob(text, analyzer=NaiveBayesAnalyzer())

# %%
blob

# %%
blob.sentiment

# %%
for sentence in blob.sentences:
    print(sentence.sentiment)

# %% [markdown]
# # 12.2.6 Self Check

# %% [markdown]
# **1. _(IPython Session)_** Check the sentiment of the three sentences in the previous Self Check this time using the `NaiveBayesAnalyzer`.
#
# **Answer:**

# %%
text = ('The food is not good. The movie was not bad. ' +
        'The movie was excellent!')

# %%
exblob = TextBlob(text, analyzer=NaiveBayesAnalyzer())

# %%
for sentence in exblob.sentences:
    print(sentence.sentiment)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4059970295.py in <cell line: 0>()
# ----> 1 for sentence in exblob.sentences:
#       2     print(sentence.sentiment)
#
# NameError: name 'exblob' is not defined

# %% [markdown]
# ## A note about Naive Bayes analysis
#
# [GeeksForGeeks](https://www.geeksforgeeks.org/machine-learning/naive-bayes-classifiers/)

# %% [markdown]
# # 12.2.7 Language Detection and Translation

# %%
blob

# %%
blob.detect_language()

# %%
spanish = blob.translate(to='es')

# %%
spanish

# %%
spanish.detect_language()

# %%
chinese = blob.translate(to='zh')

# %%
chinese

# %%
chinese.detect_language()

# %%
spanish.translate()

# %%
chinese.translate()

# %% [markdown]
# # 12.2.7 Self Check

# %% [markdown]
# **1. _(IPython Session)_** Translate `'Today is a beautiful day.'` into French, then detect the language.
#
# **Answer:**

# %%
blob = TextBlob('Today is a beautiful day.')

# %%
french = blob.translate(to='fr')

# %%
french

# %%
french.detect_language()

# %% [markdown]
# # 12.2.8 Inflection: Pluralization and Singularization

# %%
# Section 12.2.8 snippets
from textblob import Word

index = Word('index')

index.pluralize()

cacti = Word('cacti')

cacti.singularize()

from textblob import TextBlob

animals = TextBlob('dog cat fish bird').words

animals.pluralize()

# %% [markdown]
# # 12.2.8 Self Check

# %%
# Exercise 1
from textblob import Word

Word('children').singularize()

Word('focus').pluralize()

# %% [markdown]
# # 12.2.9 Spell Checking and Correction

# %%
# Section 12.2.9 snippets
from textblob import Word

word = Word('theyr')

word.spellcheck()

word.correct()  # chooses word with the highest confidence value

from textblob import TextBlob

sentence = TextBlob('Ths sentense has missplled wrds.')

sentence.correct()

# %% [markdown]
# # 12.2.9 Self Check

# %%
# Exercise 2
from textblob import TextBlob

sentence = TextBlob('I canot beleive I misspeled thees werds')

sentence.correct()

# %% [markdown]
# # 12.2.10 Normalization: Stemming and Lemmatization

# %%
# Section 12.2.10 snippets
from textblob import Word

word = Word('varieties')

word.stem()

word.lemmatize()

# %% [markdown]
# # 12.2.10 Self Check

# %%
# Exercise 2
from textblob import Word

word = Word('strawberries')

word.stem()

word.lemmatize()

# %% [markdown]
# # 12.2.11 Word Frequencies

# %%
# Section 12.2.11 snippets
# NOTE: This section's Self Check snippets are included in this file
# because the self check continues the interactive session.

from pathlib import Path

from textblob import TextBlob

blob = TextBlob(Path('RomeoAndJuliet.txt').read_text())

blob.word_counts['juliet']

blob.word_counts['romeo']

blob.word_counts['thou']

blob.words.count('joy')

blob.noun_phrases.count('lady capulet')

# %%
# Section 12.2.11 Self Check snippets

# Exercise 2
blob.word_counts['a']

blob.word_counts['an']

blob.word_counts['the']

# %% [markdown]
# # 12.2.12 Getting Definitions, Synonyms and Antonyms from WordNet

# %%
# Section 12.2.12 snippets

# Getting Definitions
from textblob import Word

happy = Word('happy')

happy.definitions

# Getting Synonyms
happy.synsets

synonyms = set()

for synset in happy.synsets:
    for lemma in synset.lemmas():
        synonyms.add(lemma.name())

synonyms

# Getting Antonyms
lemmas = happy.synsets[0].lemmas()

lemmas

lemmas[0].antonyms()

# %% [markdown]
# # 12.2.12 Self Check

# %%
# Exercise 2
from textblob import Word

word = Word('boat')

word.synsets

word.definitions

# %% [markdown]
# # 12.2.13 Deleting Stop Words

# %%
import nltk

nltk.download('stopwords')

from nltk.corpus import stopwords

stops = stopwords.words('english')

from textblob import TextBlob

blob = TextBlob('Today is a beautiful day.')

[word for word in blob.words if word not in stops]

# %% [markdown]
# # 12.2.13 Self Check

# %%
# Exercise 2
from nltk.corpus import stopwords

stops = stopwords.words('english')

from textblob import TextBlob

blob = TextBlob('TextBlob is easy to use.')

[word for word in blob.words if word not in stops]

# %% [markdown]
# # 12.2.14 n-grams

# %%
# Section 12.2.14 snippets
from textblob import TextBlob

text = 'Today is a beautiful day. Tomorrow looks like bad weather.'

blob = TextBlob(text)

blob.ngrams()

blob.ngrams(n=5)

# %% [markdown]
# # 12.2.14 Self Check

# %%
# Exercise 2
from textblob import TextBlob

blob = TextBlob('TextBlob is easy to use.')

blob.ngrams()

# %%
##########################################################################
# (C) Copyright 2019 by Deitel & Associates, Inc. and                    #
# Pearson Education, Inc. All Rights Reserved.                           #
#                                                                        #
# DISCLAIMER: The authors and publisher of this book have used their     #
# best efforts in preparing the book. These efforts include the          #
# development, research, and testing of the theories and programs        #
# to determine their effectiveness. The authors and publisher make       #
# no warranty of any kind, expressed or implied, with regard to these    #
# programs or to the documentation contained in these books. The authors #
# and publisher shall not be liable in any event for incidental or       #
# consequential damages in connection with, or arising out of, the       #
# furnishing, performance, or use of these programs.                     #
##########################################################################
